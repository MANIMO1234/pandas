# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## copy

# %%
df_copy =df.copy()

# %%
id(df_copy), id(df)
# Out:
# (4699189200, 4698045280)

# %%
df_copy.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_copy.loc[0, 'age'] =  9999

# %%
df_copy.head(1)
# Out:
#    survived  pclass   sex     age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  9999.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %% [markdown]
# ### 결측치
# 1.  결측 데이터 **확인**
# 2.  결측치가 아닌 데이터 확인
#
# ---
# 1.  결측치 체우기 # 가장 고민 해야 함
# 2.  결측 데이터 제거하기

# %%
df_copy = df.copy()

# %%
df_copy.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# - null값이 현재 포함 되어 있을까용?
#   결측치 값을 숫자로 포함 해줌 age는 177개 정도가 결측 되어 있다고 보면 된다

# %%
df_copy.isna().sum()  #  비어 있는 값에 대한 정보
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_copy.notnull().sum() # notna도 같게 작동 한다
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %% [markdown]
# ### 결측데이터 필터링

# %%
df_copy['age'].isnull()
#df_copy.loc[cond, 'age'] = 30
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
df_copy.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  30.0      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# ## fillna()

# %%
df_copy = df.copy()

# %%
df_copy.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df_copy['age'].fillna(100)
# Out:
# 0       22.0
# 1       38.0
# 2       26.0
# 3       35.0
# 4       35.0
#        ...
# 886     27.0
# 887     19.0
# 888    100.0
# 889     26.0
# 890     32.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# - 내가 가지고 있는 nan을 찾아 주고 거기 다가 내가 원하는 숫자를 넣을 수 있게 도와주는 것음
# - 직적적으로 카피를 바로 수정 하지 않고 , 연산 결과만 알려줌
# - 연산결과를 실제 카피 버전에 넣고 싶다면 ,,, 다음 과 같지
# -

# %%
df_copy['age'] = df_copy['age'].fillna(100)

# %% [markdown]
# - 자료를 완전히 바꿔 주는 것임

# %%
df_copy.tail()
# Out:
#      survived  pclass     sex    age  sibsp  parch   fare embarked   class  \
# 886         0       2    male   27.0      0      0  13.00        S  Second
# 887         1       1  female   19.0      0      0  30.00        S   First
# 888         0       3  female  100.0      1      2  23.45        S   Third
# 889         1       1    male   26.0      0      0  30.00        C   First
# 890         0       3    male   32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_copy['deck'].value_counts()
# Out:
# deck
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
df_copy['deck'].fillna('C')
# Out:
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C
#       ..
# 886    C
# 887    B
# 888    C
# 889    C
# 890    C
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df_copy['deck'] = df_copy['deck'].cat.add_categories('Z')  #카테고리라는 속상에 들어가서 카테고리를 추가

df_copy['deck'].fillna('Z')   # 내가 임으로 만드는 카테고리를 넣은 거라서 거의 쓸일 없음
# Out:
# 0      Z
# 1      C
# 2      Z
# 3      C
# 4      Z
#       ..
# 886    Z
# 887    B
# 888    Z
# 889    C
# 890    Z
# Name: deck, Length: 891, dtype: category
# Categories (8, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'Z']

# %%
 df_copy['age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df_copy['age'] = df_copy['age'].fillna(age_mean)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_copy = df.copy()

# %%
df_copy['age'] =df_copy['age'].fillna(df['age'].median())

# %%
df_copy.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  28.0      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# ###
#
#
# 남자 승객의 결측치는 남자 승객의 남자 승객의 평균
# 여자 승객의 결측치는 여자 승객의 평균
# 결측치를 모두 채우고 나서 모든 사람의 평균을 구하자

# %%
df_copy = df.copy()

# %%
df_copy.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
#  - 현재 비어 있는 것은 age, deck , embark_town

# %%
df2 = df_copy['sex'] == 'male'

# %%
age_mean = df_copy.loc[df2, 'age'].mean()   # 그중에서 남자 정보만 실행 하겠다는 거임
#deck_mane = df_copy.loc[df2 , 'deck'].mean()
#embark_mean = df_copy.loc[df2 , 'embark_town'].mean()

# %%
df_copy['age'] = df_copy['age'].fillna(age_mean)

# %%
cond2 = df['sex'] == 'female'
female_mean = df_copy.loc[cond2, 'age'].mean()
print(female_mean)
# Out:
# 28.390166125335696

# %%
df_copy.loc[df2 , 'age'] = df_copy.loc[df2 , 'age'].fillna(age_mean)
df_copy.loc[cond2 , 'age'] = df_copy.loc[cond2 ,  'age'].fillna(female_mean)

# %%
df_copy['age'].mean()
# Out:
# np.float64(29.90323916129656)

# %% [markdown]
# ## 데이터를 제거 하는 것  dropna()

# %%
df_copy =df.copy()  #nan이 한개라도 있으면 보여 주는 것임

# %%
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_copy.dropna(how = 'all') #모두다 nan인 것을  제외하고 보여줌
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
